# %% [markdown]
# <a href="https://colab.research.google.com/github/Euan-Kearney/EKStockPredictor/blob/main/model_0_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%shell
# pip install -q opendatasets
# pip install -q pandas
# pip install -q kaggle

# %%
from google.colab import userdata
import json
import os

kaggle_json_str = userdata.get('KAGGLE_JSON')
kaggle_dict = json.loads(kaggle_json_str)

os.makedirs('/root/.kaggle', exist_ok=True)
with open('/root/.kaggle/kaggle.json', 'w') as f:
    json.dump(kaggle_dict, f)
# !chmod 600 /root/.kaggle/kaggle.json
# !kaggle datasets download -d kmader/skin-cancer-mnist-ham10000 -p /content/HAM10000 --unzip --quiet
# Out:
# Dataset URL: https://www.kaggle.com/datasets/kmader/skin-cancer-mnist-ham10000
# License(s): CC-BY-NC-SA-4.0

# %%
from sklearn.model_selection import train_test_split
from pathlib import Path
import pandas as pd

base = "HAM10000_organized"
splits = ["train", "validate", "test"]
os.makedirs(base, exist_ok=True)

classes = [
    "melanoma",
    "BCC",
    "SCC",
    "precancerous",
    "low_risk",
    "unknown"
]
for split in splits:
    for cls in classes:
        path = os.path.join(base, split, cls)
        os.makedirs(path, exist_ok=True)


os.makedirs(base, exist_ok=True)

df = pd.read_csv('HAM10000/HAM10000_metadata.csv')
train, temp_df = train_test_split(df, test_size=0.2)
validate, test = train_test_split(temp_df, test_size=0.5)
